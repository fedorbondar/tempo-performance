# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('dataset_quarts_absence.csv')

# %%
df = df.set_index('author')

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#                                   period1  period2  period3  adf_c  adf_ct  \
# author
# author264_2024-04-01_2024-06-30        31       23        9      0       0
# author114_2024-07-01_2024-09-30        32       19       26      0       1
# author554_2023-10-01_2023-12-31        13       17        5      0       0
# author25_2024-07-01_2024-09-30          2        3       29      0       0
# author756_2023-07-01_2023-09-30         3        6        9      0       0
# ...                                   ...      ...      ...    ...     ...
# author184_2023-07-01_2023-09-30        26       13       12      1       1
# author1063_2023-07-01_2023-09-30        1        2        5      1       0
# author161_2023-10-01_2023-12-31        21       24       32      0       0
# author702_2023-07-01_2023-09-30        16       25        3      1       1
# author744_2024-01-01_2024-03-31        13       18       19      0       0
#
# ...

# %%
X, y = df.drop(['target'], axis=1), df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ## **1. Borders selection**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import precision_recall_fscore_support, matthews_corrcoef, accuracy_score

# %%
for l1 in range(1, 100, 1):
    for l2 in range(l1 + 1, 100, 1):
        l1_float = l1 / 100
        l2_float = l2 / 100
        y_train_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_train]
        if 1 not in y_train_classes or 2 not in y_train_classes or 3 not in y_train_classes:
            continue
        y_test_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_test]
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train_classes)
        preds = clf.predict(X_test)
        precision, recall, fscore, _ = precision_recall_fscore_support(y_true=y_test_classes, y_pred=preds, labels=[1, 2, 3], average='macro')
        mcc = matthews_corrcoef(y_test_classes, preds)
        acc = accuracy_score(y_test_classes, preds)
        print(f'\n------ l1={l1_float}, l2={l2_float}, precision={precision}, recall={recall}, fscore={fscore}, mcc={mcc}, acc={acc}\n')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## **2. Best borders**

# %%
from collections import Counter

# %%
l1_float = 0.7
l2_float = 0.8
y_train_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_train]
print(f'train occurences of classes {Counter(y_train_classes).keys()} are {Counter(y_train_classes).values()}')
y_test_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_test]
print(f'test occurences of classes {Counter(y_test_classes).keys()} are {Counter(y_test_classes).values()}')
clf = RandomForestClassifier(n_estimators=1000, random_state=42)
clf.fit(X_train, y_train_classes)
preds = clf.predict(X_test)
precision, recall, fscore, _ = precision_recall_fscore_support(y_true=y_test_classes, y_pred=preds, labels=[1, 2, 3], average=None)
mcc = matthews_corrcoef(y_test_classes, preds)
acc = accuracy_score(y_test_classes, preds)
print(f'\n------ l1={l1_float}, l2={l2_float}, \nprecision={precision}, \nrecall={recall}, \nf1score={fscore}, \nmcc={mcc}, acc={acc}\n')
# Out:
# train occurences of classes dict_keys([2, 3, 1]) are dict_values([1866, 1915, 698])
# test occurences of classes dict_keys([2, 3, 1]) are dict_values([193, 221, 84])
#
# ------ l1=0.7, l2=0.8,
# precision=[0.8        0.60444444 0.76233184],
# recall=[0.47619048 0.70466321 0.76923077],
# f1score=[0.59701493 0.6507177  0.76576577],
# mcc=0.5029166370071275, acc=0.6947791164658634

# %%
l1_float = 0.5
l2_float = 0.84
y_train_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_train]
print(f'train occurences of classes {Counter(y_train_classes).keys()} are {Counter(y_train_classes).values()}')
y_test_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_test]
print(f'test occurences of classes {Counter(y_test_classes).keys()} are {Counter(y_test_classes).values()}')
clf = RandomForestClassifier(n_estimators=1000, random_state=42)
clf.fit(X_train, y_train_classes)
preds = clf.predict(X_test)
precision, recall, fscore, _ = precision_recall_fscore_support(y_true=y_test_classes, y_pred=preds, labels=[1, 2, 3], average=None)
mcc = matthews_corrcoef(y_test_classes, preds)
acc = accuracy_score(y_test_classes, preds)
print(f'\n------ l1={l1_float}, l2={l2_float}, \nprecision={precision}, \nrecall={recall}, \nf1score={fscore}, \nmcc={mcc}, acc={acc}\n')
# Out:
# train occurences of classes dict_keys([2, 3, 1]) are dict_values([3418, 1047, 14])
# test occurences of classes dict_keys([2, 3, 1]) are dict_values([371, 125, 2])
#
# ------ l1=0.5, l2=0.84,
# precision=[0.33333333 0.80424528 0.6056338 ],
# recall=[0.5        0.91913747 0.344     ],
# f1score=[0.4        0.85786164 0.43877551],
# mcc=0.3301946503087392, acc=0.7730923694779116

# %%
l1_float = 0.64
l2_float = 0.89
y_train_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_train]
print(f'train occurences of classes {Counter(y_train_classes).keys()} are {Counter(y_train_classes).values()}')
y_test_classes = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in y_test]
print(f'test occurences of classes {Counter(y_test_classes).keys()} are {Counter(y_test_classes).values()}')
clf = RandomForestClassifier(n_estimators=1000, random_state=42)
clf.fit(X_train, y_train_classes)
preds = clf.predict(X_test)
precision, recall, fscore, _ = precision_recall_fscore_support(y_true=y_test_classes, y_pred=preds, labels=[1, 2, 3], average=None)
mcc = matthews_corrcoef(y_test_classes, preds)
acc = accuracy_score(y_test_classes, preds)
print(f'\n------ l1={l1_float}, l2={l2_float}, \nprecision={precision}, \nrecall={recall}, \nf1score={fscore}, \nmcc={mcc}, acc={acc}\n')
# Out:
# train occurences of classes dict_keys([2, 1, 3]) are dict_values([4137, 263, 79])
# test occurences of classes dict_keys([2, 1, 3]) are dict_values([452, 37, 9])
#
# ------ l1=0.64, l2=0.89,
# precision=[0.82352941 0.94315789 0.83333333],
# recall=[0.37837838 0.99115044 0.55555556],
# f1score=[0.51851852 0.96655879 0.66666667],
# mcc=0.5629138682857457, acc=0.9377510040160643

# %% [markdown]
# ## **3. Results**

# %%
pd.DataFrame({'features': X.columns, 'feature_importances': clf.feature_importances_})
# Out:
#    features  feature_importances
# 0   period1             0.079350
# 1   period2             0.085666
# 2   period3             0.085322
# 3     adf_c             0.005727
# 4    adf_ct             0.006117
# 5   adf_ctt             0.008786
# 6      pp_c             0.002486
# 7     pp_ct             0.003454
# 8    kpss_c             0.004029
# 9   kpss_ct             0.003973
# 10      max             0.111933
# 11    shift             0.012708
# 12     mean             0.210909
# 13      var             0.152307
# 14        0             0.046117
# 15        1             0.040310
# 16        2             0.042075
# 17        3             0.040338
# 18        4             0.045926
# 19   daily0             0.002666
# 20   daily1             0.002658
# 21   daily2             0.004490
# 22  weekly0             0.000813
# 23  weekly1             0.000895
# 24  weekly2             0.000944

# %%
df['target_class'] = [1 if y_i < l1_float else 2 if l1_float <= y_i and y_i < l2_float else 3 for y_i in df['target']]

# %%
df.target_class.value_counts()
# Out:
# target_class
# 2    4589
# 1     300
# 3      88
# Name: count, dtype: int64

# %%
df[df['target_class'] == 1].describe().T
# Out:
#               count        mean         std        min         25%  \
# period1       300.0   18.326667    8.911679   1.000000   10.000000
# period2       300.0   18.333333    8.672539   1.000000   11.750000
# period3       300.0   17.843333    9.122657   1.000000   10.000000
# adf_c         300.0    0.040000    0.196287   0.000000    0.000000
# adf_ct        300.0    0.056667    0.231591   0.000000    0.000000
# adf_ctt       300.0    0.086667    0.281816   0.000000    0.000000
# pp_c          300.0    0.006667    0.081513   0.000000    0.000000
# pp_ct         300.0    0.006667    0.081513   0.000000    0.000000
# kpss_c        300.0    0.000000    0.000000   0.000000    0.000000
# kpss_ct       300.0    0.003333    0.057735   0.000000    0.000000
# max           300.0  129.596767   59.261828  11.000000   88.000000
# mean          300.0    8.643697    1.610725   3.136364    7.878322
# var           300.0  526.127991  453.043939   5.602071  228.917041
# ...

# %%
df[df['target_class'] == 2].describe().T
# Out:
#                count        mean         std       min        25%         50%  \
# period1       4589.0   18.181957    9.286009  1.000000  12.000000   19.000000
# period2       4589.0   18.457616    8.970102  1.000000  12.000000   20.000000
# period3       4589.0   18.692308    8.887796  1.000000  12.000000   20.000000
# adf_c         4589.0    0.105470    0.307191  0.000000   0.000000    0.000000
# adf_ct        4589.0    0.120723    0.325841  0.000000   0.000000    0.000000
# adf_ctt       4589.0    0.132709    0.339297  0.000000   0.000000    0.000000
# pp_c          4589.0    0.006537    0.080598  0.000000   0.000000    0.000000
# pp_ct         4589.0    0.007191    0.084504  0.000000   0.000000    0.000000
# kpss_c        4589.0    0.076487    0.265805  0.000000   0.000000    0.000000
# kpss_ct       4589.0    0.104816    0.306349  0.000000   0.000000    0.000000
# max           4589.0   76.638106   49.535463  0.000000  40.000000   64.000000
# ...

# %%
df[df['target_class'] == 3].describe().T
# Out:
#               count       mean        std       min        25%        50%  \
# period1        88.0  12.500000  11.714025  1.000000   1.000000  11.000000
# period2        88.0  12.681818  10.578166  1.000000   2.000000  11.000000
# period3        88.0  14.875000  10.420815  1.000000   3.000000  16.000000
# adf_c          88.0   0.272727   0.447914  0.000000   0.000000   0.000000
# adf_ct         88.0   0.284091   0.453565  0.000000   0.000000   0.000000
# adf_ctt        88.0   0.295455   0.458861  0.000000   0.000000   0.000000
# pp_c           88.0   0.102273   0.304743  0.000000   0.000000   0.000000
# pp_ct          88.0   0.113636   0.319188  0.000000   0.000000   0.000000
# kpss_c         88.0   0.193182   0.397057  0.000000   0.000000   0.000000
# kpss_ct        88.0   0.329545   0.472742  0.000000   0.000000   0.000000
# max            88.0  27.593750  21.903126  3.000000  16.000000  16.541667
# mean           88.0   4.037260   2.978868  0.045455   0.606061   5.129720
# ...

# %%
from utils.data_loader import DataLoader
from utils.data_builder import DataBuilder
from reports.time_series import simple_tempo_worklog_report

# %%
dl = DataLoader('tempo_db_masked.csv')
db = DataBuilder(dl.get_data())

# %%
df[df['target_class'] == 1].sample(random_state=42)
# Out:
#                                  period1  period2  period3  adf_c  adf_ct  \
# author
# author255_2023-10-01_2023-12-31       11       24       21      0       0
#
#                                  adf_ctt  pp_c  pp_ct  kpss_c  kpss_ct  ...  \
# author                                                                  ...
# author255_2023-10-01_2023-12-31        0     0      0       0        0  ...
#
#                                    3    4  daily0  daily1  daily2  weekly0  \
# author
# author255_2023-10-01_2023-12-31  0.0  0.0       1       1       1        1
#
#                                  weekly1  weekly2    target  target_class
# author
# author255_2023-10-01_2023-12-31        1        1  0.597308             1
#
# [1 rows x 27 columns]

# %%
simple_tempo_worklog_report(db, 'author255', '2023-10-01', '2023-11-15', ignore_weekends=True)

# %%
simple_tempo_worklog_report(db, 'author255', '2023-11-16', '2023-12-31', ignore_weekends=True)

# %%
df[df['target_class'] == 2].sample(random_state=42)
# Out:
#                                  period1  period2  period3  adf_c  adf_ct  \
# author
# author106_2024-07-01_2024-09-30       26       13       17      0       0
#
#                                  adf_ctt  pp_c  pp_ct  kpss_c  kpss_ct  ...  \
# author                                                                  ...
# author106_2024-07-01_2024-09-30        0     0      0       0        0  ...
#
#                                    3     4  daily0  daily1  daily2  weekly0  \
# author
# author106_2024-07-01_2024-09-30  2.3  14.7       1       1       1        1
#
#                                  weekly1  weekly2    target  target_class
# author
# author106_2024-07-01_2024-09-30        1        1  0.788413             2
#
# [1 rows x 27 columns]

# %%
simple_tempo_worklog_report(db, 'author106', '2024-07-01', '2024-08-15', ignore_weekends=True)

# %%
simple_tempo_worklog_report(db, 'author106', '2024-08-16', '2024-09-30', ignore_weekends=True)

# %%
df[df['target_class'] == 3].sample(random_state=42)
# Out:
#                                  period1  period2  period3  adf_c  adf_ct  \
# author
# author932_2023-10-01_2023-12-31       25       22        8      0       0
#
#                                  adf_ctt  pp_c  pp_ct  kpss_c  kpss_ct  ...  \
# author                                                                  ...
# author932_2023-10-01_2023-12-31        0     0      0       0        0  ...
#
#                                    3    4  daily0  daily1  daily2  weekly0  \
# author
# author932_2023-10-01_2023-12-31  0.0  0.0       1       1       1        1
#
#                                  weekly1  weekly2    target  target_class
# author
# author932_2023-10-01_2023-12-31        1        1  0.899902             3
#
# [1 rows x 27 columns]

# %%
simple_tempo_worklog_report(db, 'author932', '2023-10-01', '2023-11-15', ignore_weekends=True)

# %%
simple_tempo_worklog_report(db, 'author932', '2023-11-16', '2023-12-31', ignore_weekends=True)
